# %% [markdown]
# # Midterm Project (SEG Dataset)
# ## Facies classification using Machine Learning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from mpl_toolkits.axes_grid1 import make_axes_locatable
import seaborn as sns
import numpy as np
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import IsolationForest, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, recall_score, precision_score, classification_report, confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC, SVC

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1. Load, Visualization and Exploration of Data

# %% [markdown]
# ### 1.1. Data Load

# %%
#Load data
data = pd.read_csv('Facies_vectors.csv')
data
# Out:
#       Facies Formation        Well Name   Depth      GR  ILD_log10  DeltaPHI  \
# 0          3     A1 SH        SHRIMPLIN  2793.0  77.450      0.664     9.900
# 1          3     A1 SH        SHRIMPLIN  2793.5  78.260      0.661    14.200
# 2          3     A1 SH        SHRIMPLIN  2794.0  79.050      0.658    14.800
# 3          3     A1 SH        SHRIMPLIN  2794.5  86.100      0.655    13.900
# 4          3     A1 SH        SHRIMPLIN  2795.0  74.580      0.647    13.500
# ...      ...       ...              ...     ...     ...        ...       ...
# 4144       5      C LM  CHURCHMAN BIBLE  3120.5  46.719      0.947     1.828
# 4145       5      C LM  CHURCHMAN BIBLE  3121.0  44.563      0.953     2.241
# 4146       5      C LM  CHURCHMAN BIBLE  3121.5  49.719      0.964     2.925
# 4147       5      C LM  CHURCHMAN BIBLE  3122.0  51.469      0.965     3.083
# 4148       5      C LM  CHURCHMAN BIBLE  3122.5  50.031      0.970     2.609
#
#        PHIND     PE  NM_M  RELPOS
# 0     11.915  4.600     1   1.000
# 1     12.565  4.100     1   0.979
# 2     13.050  3.600     1   0.957
# 3     13.115  3.500     1   0.936
# 4     13.300  3.400     1   0.915
# ...      ...    ...   ...     ...
# 4144   7.254  3.617     2   0.685
# 4145   8.013  3.344     2   0.677
# 4146   8.013  3.190     2   0.669
# 4147   7.708  3.152     2   0.661
# 4148   6.668  3.295     2   0.653
#
# [4149 rows x 11 columns]

# %%
#Label of Facies
labels = ['SS', 'CSiS', 'FSiS', 'SiSh', 'MS','WS', 'D','PS', 'BS'] 
data['Facies_Label']=np.select([data['Facies'] == 1,
                                data['Facies'] == 2,
                                data['Facies'] == 3,
                                data['Facies'] == 4,
                                data['Facies'] == 5,
                                data['Facies'] == 6,
                                data['Facies'] == 7,
                                data['Facies'] == 8,
                                data['Facies'] == 9,]
                                ,labels,default='')

# %%
#Unique items in a column that is categorical
data['Well Name'] = data['Well Name'].astype('category')
data['Formation'] = data['Formation'].astype('category')
data['Facies_Label'] = data['Facies_Label'].astype('category')

# %%
data
# Out:
#       Facies Formation        Well Name   Depth      GR  ILD_log10  DeltaPHI  \
# 0          3     A1 SH        SHRIMPLIN  2793.0  77.450      0.664     9.900
# 1          3     A1 SH        SHRIMPLIN  2793.5  78.260      0.661    14.200
# 2          3     A1 SH        SHRIMPLIN  2794.0  79.050      0.658    14.800
# 3          3     A1 SH        SHRIMPLIN  2794.5  86.100      0.655    13.900
# 4          3     A1 SH        SHRIMPLIN  2795.0  74.580      0.647    13.500
# ...      ...       ...              ...     ...     ...        ...       ...
# 4144       5      C LM  CHURCHMAN BIBLE  3120.5  46.719      0.947     1.828
# 4145       5      C LM  CHURCHMAN BIBLE  3121.0  44.563      0.953     2.241
# 4146       5      C LM  CHURCHMAN BIBLE  3121.5  49.719      0.964     2.925
# 4147       5      C LM  CHURCHMAN BIBLE  3122.0  51.469      0.965     3.083
# 4148       5      C LM  CHURCHMAN BIBLE  3122.5  50.031      0.970     2.609
#
#        PHIND     PE  NM_M  RELPOS Facies_Label
# 0     11.915  4.600     1   1.000         FSiS
# 1     12.565  4.100     1   0.979         FSiS
# 2     13.050  3.600     1   0.957         FSiS
# 3     13.115  3.500     1   0.936         FSiS
# 4     13.300  3.400     1   0.915         FSiS
# ...      ...    ...   ...     ...          ...
# 4144   7.254  3.617     2   0.685           MS
# 4145   8.013  3.344     2   0.677           MS
# 4146   8.013  3.190     2   0.669           MS
# 4147   7.708  3.152     2   0.661           MS
# 4148   6.668  3.295     2   0.653           MS
#
# [4149 rows x 12 columns]

# %% [markdown]
# ### 1.2. Visualization

# %%
sns.pairplot(data.drop(['Facies','NM_M','RELPOS','Depth'], axis = 1) ,hue='Facies_Label',diag_kind='hist')

# %% [markdown]
# #### Well logs plot

# %%
# 1=sandstone  2=c_siltstone   3=f_siltstone 
# 4=marine_silt_shale 5=mudstone 6=wackestone 7=dolomite
# 8=packstone 9=bafflestone
facies_colors = ['#F4D03F', '#F5B041','#DC7633','#6E2C00',
       '#1B4F72','#2E86C1', '#AED6F1', '#A569BD', '#196F3D']

facies_labels = ['SS', 'CSiS', 'FSiS', 'SiSh', 'MS',
                 'WS', 'D','PS', 'BS']

def make_facies_log_plot(logs, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster=np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=6, figsize=(8, 12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.ILD_log10, logs.Depth, '-')
    ax[2].plot(logs.DeltaPHI, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.PHIND, logs.Depth, '-', color='r')
    ax[4].plot(logs.PE, logs.Depth, '-', color='black')
    im=ax[5].imshow(cluster, interpolation='none', aspect='auto',
                   cmap=cmap_facies,vmin=1,vmax=9)
    
    divider = make_axes_locatable(ax[5])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS', 
                                'SiSh', ' MS ', ' WS ', ' D  ', 
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-1):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
    
    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("ILD_log10")
    ax[1].set_xlim(logs.ILD_log10.min(),logs.ILD_log10.max())
    ax[2].set_xlabel("DeltaPHI")
    ax[2].set_xlim(logs.DeltaPHI.min(),logs.DeltaPHI.max())
    ax[3].set_xlabel("PHIND")
    ax[3].set_xlim(logs.PHIND.min(),logs.PHIND.max())
    ax[4].set_xlabel("PE")
    ax[4].set_xlim(logs.PE.min(),logs.PE.max())
    ax[5].set_xlabel('Facies')
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    f.suptitle('Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)

# %%
make_facies_log_plot(
    data[data['Well Name'] == 'SHRIMPLIN'],
    facies_colors)

# %%
#Bar chart: Distribution of Facies
Facies_dist = data['Facies_Label'].value_counts().sort_index()

Facies_dist.plot(kind='bar',color=facies_colors, 
                   title='Distribution of Facies')

# %% [markdown]
# ### 1.3. Exploration

# %%
#Set Index Depth
data.set_index('Depth',inplace=True)

# %%
#Group by Well Name
data.groupby("Well Name").count()
# Out:
#                  Facies  Formation   GR  ILD_log10  DeltaPHI  PHIND   PE  \
# Well Name
# ALEXANDER D         466        466  466        466       466    466    0
# CHURCHMAN BIBLE     404        404  404        404       404    404  404
# CROSS H CATTLE      501        501  501        501       501    501  501
# KIMZEY A            439        439  439        439       439    439    0
# LUKE G U            461        461  461        461       461    461  461
# NEWBY               463        463  463        463       463    463  463
# NOLAN               415        415  415        415       415    415  415
# Recruit F9           80         80   80         80        80     80   68
# SHANKLE             449        449  449        449       449    449  449
# SHRIMPLIN           471        471  471        471       471    471  471
#
#                  NM_M  RELPOS  Facies_Label
# Well Name
# ALEXANDER D       466     466           466
# CHURCHMAN BIBLE   404     404           404
# CROSS H CATTLE    501     501           501
# KIMZEY A          439     439           439
# LUKE G U          461     461           461
# NEWBY             463     463           463
# NOLAN             415     415           415
# Recruit F9         80      80            80
# SHANKLE           449     449           449
# SHRIMPLIN         471     471           471

# %%
#Data Info (For dtype and NaN analysis)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 4149 entries, 2793.0 to 3122.5
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Facies        4149 non-null   int64
#  1   Formation     4149 non-null   category
#  2   Well Name     4149 non-null   category
#  3   GR            4149 non-null   float64
#  4   ILD_log10     4149 non-null   float64
#  5   DeltaPHI      4149 non-null   float64
#  6   PHIND         4149 non-null   float64
#  7   PE            3232 non-null   float64
#  8   NM_M          4149 non-null   int64
#  9   RELPOS        4149 non-null   float64
#  10  Facies_Label  4149 non-null   category
# dtypes: category(3), float64(6), int64(2)
# memory usage: 305.4 KB

# %% [markdown]
# #### Remove missing data

# %% [markdown]
# Option 1

# %%
#Delete Rows with Missing Data
data = data.dropna()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 3232 entries, 2793.0 to 3122.5
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Facies        3232 non-null   int64
#  1   Formation     3232 non-null   category
#  2   Well Name     3232 non-null   category
#  3   GR            3232 non-null   float64
#  4   ILD_log10     3232 non-null   float64
#  5   DeltaPHI      3232 non-null   float64
#  6   PHIND         3232 non-null   float64
#  7   PE            3232 non-null   float64
#  8   NM_M          3232 non-null   int64
#  9   RELPOS        3232 non-null   float64
#  10  Facies_Label  3232 non-null   category
# dtypes: category(3), float64(6), int64(2)
# memory usage: 238.2 KB

# %% [markdown]
# Option 2

# %%
#Fill missing values with median for column 'PE' in well Recruit F9
#data = data[(data['Well Name'] != 'KIMZEY A') & (data['Well Name'] != 'ALEXANDER D')]
#Rec_F9 = data[data['Well Name'] == "Recruit F9"]
#med=Rec_F9['PE'].median()
#data=data.fillna(value={'PE': med})

# %% [markdown]
# #### Accuracy Evaluation in well "SHANKLE"

# %%
#Using well "SHANKLE" for accuracy evaluation
test_well = data[data['Well Name'] == 'SHANKLE'] #New data to test
data = data[data['Well Name'] != 'SHANKLE']

# %%
X = data.drop(['Facies','Formation','Well Name','Facies_Label'], axis = 1) #Features: Feature vector
y = data['Facies'] #Target: Facies

# %%
X
# Out:
#             GR  ILD_log10  DeltaPHI   PHIND     PE  NM_M  RELPOS
# Depth
# 2793.0  77.450      0.664     9.900  11.915  4.600     1   1.000
# 2793.5  78.260      0.661    14.200  12.565  4.100     1   0.979
# 2794.0  79.050      0.658    14.800  13.050  3.600     1   0.957
# 2794.5  86.100      0.655    13.900  13.115  3.500     1   0.936
# 2795.0  74.580      0.647    13.500  13.300  3.400     1   0.915
# ...        ...        ...       ...     ...    ...   ...     ...
# 3120.5  46.719      0.947     1.828   7.254  3.617     2   0.685
# 3121.0  44.563      0.953     2.241   8.013  3.344     2   0.677
# 3121.5  49.719      0.964     2.925   8.013  3.190     2   0.669
# 3122.0  51.469      0.965     3.083   7.708  3.152     2   0.661
# 3122.5  50.031      0.970     2.609   6.668  3.295     2   0.653
#
# [2783 rows x 7 columns]

# %% [markdown]
# ## 2. Data Split (Test/Train)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1000)
print('Dimensions of X_train:',X_train.shape)
print('Dimensions of X_test:',X_test.shape)
# Out:
# Dimensions of X_train: (1948, 7)
# Dimensions of X_test: (835, 7)

# %%
X_train.hist()
plt.show()

# %%
X_train
# Out:
#             GR  ILD_log10  DeltaPHI   PHIND     PE  NM_M  RELPOS
# Depth
# 2931.5  46.813   0.857000    -0.436   4.880  4.273     2   0.902
# 3004.0  49.860   0.910000     7.600   7.585  4.800     2   0.480
# 2714.0  15.340   0.792000     0.100   9.750  5.300     2   0.789
# 3121.5  49.719   0.964000     2.925   8.013  3.190     2   0.669
# 2857.5  90.313   0.581000     5.634  13.458  3.395     1   0.818
# ...        ...        ...       ...     ...    ...   ...     ...
# 2809.0  23.688   0.777572    -2.200   9.400  4.449     2   0.971
# 2927.0  53.125   0.826000     1.122   4.835  4.008     2   1.000
# 2927.5  73.970   0.498000     5.900  16.850  3.500     1   0.222
# 2674.5  76.510   0.623000     6.600  23.600  2.600     1   0.795
# 2866.5  59.625   0.292000     6.294  19.487  2.947     1   0.409
#
# [1948 rows x 7 columns]

# %% [markdown]
# #### Dimensionality Reduction (Drop PE)

# %%
#Dimensionality Reduction (PE)
#X_train=X_train.drop(['PE'], axis = 1)
#X_test=X_test.drop(['PE'], axis = 1)

# %% [markdown]
# ## 3. Data Preprocessing

# %% [markdown]
# ### 3.1. Feature Transform: Robust Scaler

# %%
# Robust Scaler
rscaler = RobustScaler() #instantiate
rscaler.fit(X_train)
# Out:
# RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)

# %%
X_train_scaled = rscaler.transform(X_train) # transform the train dataset to standardized data

# Original training dataset
print("Original median : %s " % rscaler.center_)
print("Original IQR : %s " % rscaler.scale_)

#Scaled training dataset
print("Scaled median : %s " % np.median(X_train_scaled,axis=0))
print("Scaled IQR : %s " % (np.percentile(X_train_scaled, 75,axis=0)-np.percentile(X_train_scaled, 25,axis=0)))
# Out:
# Original median : [65.1225  0.631   3.4995 11.85    3.608   2.      0.5435]
# Original IQR : [35.7625   0.314    5.19425  7.97225  1.2      1.       0.505  ]
# Scaled median : [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.85019101e-16 0.00000000e+00 0.00000000e+00]
# Scaled IQR : [1. 1. 1. 1. 1. 1. 1.]

# %%
#Scale the test data using the parameters learnt from the training dataset
X_test_scaled  = rscaler.transform(X_test)

print("Median of scaled test data: %s" % np.median(X_test_scaled,axis=0))
print("IQR of scaled test data: %s " % (np.percentile(X_test_scaled, 75,axis=0)-np.percentile(X_test_scaled, 25,axis=0)))
# Out:
# Median of scaled test data: [ 0.04727019 -0.03327247  0.03860038  0.02333093 -0.00666667  0.
#  -0.08613861]
# IQR of scaled test data: [0.93463824 1.00955414 1.00110699 1.00034495 1.         1.
#  0.93069307]

# %%
pd.DataFrame(X_train_scaled,index=X_train.index, columns=X_test.columns).hist()
plt.show()

# %%
X_train=pd.DataFrame(X_train_scaled,index=X_train.index, columns=X_test.columns)
X_test=pd.DataFrame(X_test_scaled,index=X_test.index, columns=X_test.columns)

# %%
X_train
# Out:
#               GR  ILD_log10  DeltaPHI     PHIND        PE  NM_M    RELPOS
# Depth
# 2931.5 -0.511975   0.719745 -0.757665 -0.874283  0.554167   0.0  0.709901
# 3004.0 -0.426774   0.888535  0.789431 -0.534981  0.993333   0.0 -0.125743
# 2714.0 -1.392031   0.512739 -0.654474 -0.263414  1.410000   0.0  0.486139
# 3121.5 -0.430717   1.060510 -0.110603 -0.481294 -0.348333   0.0  0.248515
# 2857.5  0.704383  -0.159236  0.410935  0.201700 -0.177500  -1.0  0.543564
# ...          ...        ...       ...       ...       ...   ...       ...
# 2809.0 -1.158602   0.466789 -1.097271 -0.307316  0.700833   0.0  0.846535
# 2927.0 -0.335477   0.621019 -0.457718 -0.879927  0.333333   0.0  0.903960
# 2927.5  0.247396  -0.423567  0.462146  0.627176 -0.090000  -1.0 -0.636634
# 2674.5  0.318420  -0.025478  0.596910  1.473862 -0.840000  -1.0  0.498020
# 2866.5 -0.153722  -1.079618  0.537999  0.957948 -0.550833  -1.0 -0.266337
#
# [1948 rows x 7 columns]

# %% [markdown]
# ### 3.2. Outlier Detection: Isolation Forest

# %%
# Isolation Forest
iforest = IsolationForest(n_estimators=200, contamination=0.08)
iforest = iforest.fit(X_train) #Training the model

# %%
#Predictions
X_train_predict = iforest.predict(X_train) 
X_train['Predict']=X_train_predict
X_train['Predict'] = X_train['Predict'].astype('category')
X_train
# Out:
#               GR  ILD_log10  DeltaPHI     PHIND        PE  NM_M    RELPOS  \
# Depth
# 2931.5 -0.511975   0.719745 -0.757665 -0.874283  0.554167   0.0  0.709901
# 3004.0 -0.426774   0.888535  0.789431 -0.534981  0.993333   0.0 -0.125743
# 2714.0 -1.392031   0.512739 -0.654474 -0.263414  1.410000   0.0  0.486139
# 3121.5 -0.430717   1.060510 -0.110603 -0.481294 -0.348333   0.0  0.248515
# 2857.5  0.704383  -0.159236  0.410935  0.201700 -0.177500  -1.0  0.543564
# ...          ...        ...       ...       ...       ...   ...       ...
# 2809.0 -1.158602   0.466789 -1.097271 -0.307316  0.700833   0.0  0.846535
# 2927.0 -0.335477   0.621019 -0.457718 -0.879927  0.333333   0.0  0.903960
# 2927.5  0.247396  -0.423567  0.462146  0.627176 -0.090000  -1.0 -0.636634
# 2674.5  0.318420  -0.025478  0.596910  1.473862 -0.840000  -1.0  0.498020
# 2866.5 -0.153722  -1.079618  0.537999  0.957948 -0.550833  -1.0 -0.266337
#
#        Predict
# Depth
# 2931.5       1
# 3004.0       1
# 2714.0       1
# 3121.5       1
# 2857.5       1
# ...        ...
# 2809.0       1
# 2927.0       1
# 2927.5       1
# 2674.5       1
# 2866.5       1
#
# [1948 rows x 8 columns]

# %%
#Visualization
sns.pairplot(X_train.drop(['NM_M','RELPOS'],axis=1),hue='Predict',diag_kind='hist')

# %%
#Removing Outliers
X_train['y_train']=y_train
X_train = X_train[X_train['Predict'] == 1]

y_train=X_train['y_train']
X_train = X_train.drop(['Predict','y_train'], axis = 1)

# %%
print(len(X_train))
print(len(y_train))
# Out:
# 1792
# 1792

# %%
#Visualization Without Outliers
sns.pairplot(X_train.drop(['NM_M','RELPOS'],axis=1),diag_kind='hist')

# %% [markdown]
# ## 4. Models

# %% [markdown]
# ### 4.1. Logistic Regression

# %% [markdown]
# #### Tuning Hyperparameters

# %%
score=[]
score_train=[]
C=[]
for i in range(1,100,1):
    C.append(i/10)
    classifier = LogisticRegression(penalty='l2',C=i/10) 
    classifier.fit(X_train, y_train)
    train_pred = classifier.predict(X_train)
    score_train.append(f1_score(y_train, train_pred,average="weighted"))
    y_pred = classifier.predict(X_test)
    score.append(f1_score(y_test, y_pred,average="weighted"))

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('C')
ax1.set_ylabel('F1_score')
ax1.set_ylim([0.5,0.60])
ax1.plot(C, score, '-o',color=color,label='Test F1_score')

color = 'tab:blue'
ax1.plot(C, score_train, '-o',color=color,label='Train F1_score')

ax1.legend(loc="lower right")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# #### Applying Model

# %%
classifier = LogisticRegression(C=2) 
classifier.fit(X_train, y_train)

print(classifier.coef_) #a1 and a2
print(classifier.intercept_) # a0
# Out:
# [[-5.53707763e-01 -2.02933643e+00 -3.58646745e-01 -1.69889542e+00
#   -3.14868195e+00 -3.77046498e+00  4.58419594e-02]
#  [ 5.10053518e-01  4.96275424e-01 -4.43408534e-02  1.26796579e-01
#   -1.42312064e+00 -5.08698426e+00 -1.21669365e-04]
#  [ 1.07643472e+00  4.25464750e-01  1.91464267e-01  1.67880116e+00
#    1.11878616e-01 -4.17999305e+00  7.39840004e-01]
#  [ 1.00320148e+00  1.07625432e+00  8.49642497e-01  2.65948201e-01
#   -1.00045411e+00  2.58207417e+00 -6.90851777e-01]
#  [-3.04264011e-01  1.00496820e+00  7.77253551e-01 -7.14780611e-01
#    3.73508500e-02  1.78652477e+00  5.02335830e-01]
#  [-1.49565984e-01  1.02721459e+00  1.06889738e-01 -9.82697497e-01
#    5.57361505e-01  2.41717158e+00 -3.58229080e-01]
#  [-5.45224032e-01 -2.14193704e+00  7.81709911e-01 -8.25716079e-01
#    3.23430108e-02  2.78569281e+00  3.42874780e-01]
#  [-4.90034176e-01 -2.31675420e-01 -7.52957818e-01 -1.84952795e-01
#    1.48194904e+00  1.65404585e+00  2.21615037e-01]
#  [-5.46893756e-01  3.72771602e-01 -1.55101455e+00  2.33549647e+00
#    3.35137367e+00  1.81193312e+00 -8.03305083e-01]]
# [-2.24637237 -1.00587881 -1.15613234  1.35574027  1.0937482   1.51286703
#   0.27925044  1.8215162  -1.65473864]

# %%
prediction = classifier.predict(X_test)

# %%
#Compare against true labels (Accuracy)
print('Accuracy (generalization)',classifier.score(X_test,y_test)) #Accuracy (generalization)  
print('Accuracy (memorization)',classifier.score(X_train,y_train)) #Accuracy (memorization)
# Out:
# Accuracy (generalization) 0.5748502994011976
# Accuracy (memorization) 0.5998883928571429

# %%
#Comparing other metrics (f1_score)
print('F1_score (generalization)',f1_score(y_test,classifier.predict(X_test),average="weighted")) #Accuracy (generalization)  
print('F1_score (memorization)',f1_score(y_train,classifier.predict(X_train),average="weighted")) #Accuracy (memorization)
# Out:
# F1_score (generalization) 0.5577090906398687
# F1_score (memorization) 0.5878461876008334

# %% [markdown]
# ### 4.2. K-Nearest Neighbor

# %% [markdown]
# #### Tuning Hyperparameters

# %%
#Number of trees
score_gen=[]
score_mem=[]
n_neighbors=[]
for i in range(1,22,2):
    n_neighbors.append(i)
    knn = KNeighborsClassifier(n_neighbors=i,p=1)    #Creating Instance
    knn.fit(X_train, y_train) #Learning the decision boundaries
    train_pred = knn.predict(X_train)
    score_mem.append(f1_score(y_train, train_pred,average="weighted"))
    y_pred = knn.predict(X_test)
    score_gen.append(f1_score(y_test, y_pred,average="weighted"))

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('n_neighbors')
ax1.set_ylabel('Score')
ax1.set_ylim([0.4,1.01])
ax1.plot(n_neighbors, score_gen, '-o',color=color,label='Test F1_score')

color = 'tab:blue'
ax1.plot(n_neighbors, score_mem, '-o',color=color,label='Train F1_score')

ax1.legend(loc="Upper right")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
#Proximity (p)
score_gen=[]
score_mem=[]
prox=[]
for i in range(1,20,1):
    prox.append(i)
    knn = KNeighborsClassifier(n_neighbors=9,p=i)    #Creating Instance
    knn.fit(X_train, y_train) #Learning the decision boundaries
    train_pred = knn.predict(X_train)
    score_mem.append(f1_score(y_train, train_pred,average="weighted"))
    y_pred = knn.predict(X_test)
    score_gen.append(f1_score(y_test, y_pred,average="weighted"))

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Proximity (p)')
ax1.set_ylabel('Score')
ax1.set_ylim([0.4,1.01])
ax1.plot(prox, score_gen, '-o',color=color,label='Test F1_score')

color = 'tab:blue'
ax1.plot(prox, score_mem, '-o',color=color,label='Train F1_score')

ax1.legend(loc="Upper right")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# #### Applying Model

# %%
knn = KNeighborsClassifier(n_neighbors=9,p=1)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=9, p=1,
#                      weights='uniform')

# %%
#Compare against true labels (Accuracy)
print('Accuracy (generalization)',knn.score(X_test,y_test)) #Accuracy (generalization)  
print('Accuracy (memorization)',knn.score(X_train,y_train)) #Accuracy (memorization)
# Out:
# Accuracy (generalization) 0.6754491017964072
# Accuracy (memorization) 0.73828125

# %%
#Comparing other metrics (f1_score)
print('F1_score (generalization)',f1_score(y_test,knn.predict(X_test),average="weighted")) #F1_score (generalization)  
print('F1_score (memorization)',f1_score(y_train,knn.predict(X_train),average="weighted")) #F1_score (memorization
# Out:
# F1_score (generalization) 0.6700086409843371
# F1_score (memorization) 0.7370021329258629

# %% [markdown]
# ### 4.3. Support Vector Machine

# %% [markdown]
# #### Tuning Hyperparameters

# %%
from sklearn.model_selection import GridSearchCV 
  
#Defining parameter range 
Tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
                     'C': [0.1, 1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]},
                    {'kernel': ['poly'],'C': [1, 10, 100, 1000],'degree': [2,3,4]}]
  
svc_mod = GridSearchCV(SVC(), Tuned_parameters, refit = True, verbose = 3)

# %%
svc_mod.fit(X_train, y_train) 
svc_mod.best_estimator_
# Out:
# Fitting 5 folds for each of 41 candidates, totalling 205 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.563, total=   0.2s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.554, total=   0.2s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.575, total=   0.2s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.584, total=   0.2s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.573, total=   0.2s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.501, total=   0.2s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.496, total=   0.2s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.534, total=   0.2s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.511, total=   0.2s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.525, total=   0.2s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.382, total=   0.2s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.370, total=   0.2s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.388, total=   0.2s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.402, total=   0.2s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.380, total=   0.2s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.234, total=   0.2s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.234, total=   0.2s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.237, total=   0.2s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.237, total=   0.2s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.235, total=   0.2s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.234, total=   0.2s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.234, total=   0.2s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.237, total=   0.2s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.237, total=   0.2s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.235, total=   0.2s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.669, total=   0.2s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.680, total=   0.2s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.665, total=   0.2s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.682, total=   0.2s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.654, total=   0.2s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.585, total=   0.1s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.588, total=   0.1s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.598, total=   0.1s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.628, total=   0.1s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.612, total=   0.1s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.515, total=   0.2s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.504, total=   0.2s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.550, total=   0.2s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.520, total=   0.1s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.514, total=   0.2s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.384, total=   0.2s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.370, total=   0.2s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.388, total=   0.2s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.402, total=   0.2s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.383, total=   0.2s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.234, total=   0.2s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.234, total=   0.2s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.237, total=   0.2s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.237, total=   0.2s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.235, total=   0.2s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.730, total=   0.2s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.705, total=   0.2s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.721, total=   0.2s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.698, total=   0.2s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.698, total=   0.2s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.610, total=   0.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.613, total=   0.2s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.637, total=   0.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.640, total=   0.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.615, total=   0.2s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.579, total=   0.2s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.602, total=   0.2s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.603, total=   0.2s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.606, total=   0.2s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.575, total=   0.2s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.513, total=   0.2s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.507, total=   0.2s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.550, total=   0.2s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.520, total=   0.2s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.520, total=   0.2s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.384, total=   0.2s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.370, total=   0.2s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.388, total=   0.2s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.402, total=   0.2s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.383, total=   0.2s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.677, total=   0.2s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.666, total=   0.2s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.701, total=   0.3s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.715, total=   0.3s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.676, total=   0.3s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.646, total=   0.2s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.652, total=   0.2s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.654, total=   0.2s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.676, total=   0.2s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.626, total=   0.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.565, total=   0.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.602, total=   0.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.615, total=   0.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.640, total=   0.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.598, total=   0.1s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.579, total=   0.2s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.591, total=   0.2s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.601, total=   0.2s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.603, total=   0.2s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.575, total=   0.3s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.513, total=   0.2s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.507, total=   0.2s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.550, total=   0.2s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.520, total=   0.2s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.520, total=   0.2s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.655, total=   0.3s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.635, total=   0.3s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.687, total=   0.3s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.718, total=   0.3s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.673, total=   0.3s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.682, total=   0.8s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.677, total=   0.7s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.668, total=   0.6s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.676, total=   0.7s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.656, total=   0.7s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.610, total=   0.3s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.613, total=   0.3s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.640, total=   0.3s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.659, total=   0.3s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.617, total=   0.3s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.582, total=   0.2s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.602, total=   0.2s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.601, total=   0.2s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.606, total=   0.2s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.581, total=   0.2s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.582, total=   0.2s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.585, total=   0.2s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.603, total=   0.2s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.598, total=   0.2s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.575, total=   0.2s
# [CV] C=1, kernel=linear ..............................................
# [CV] .................. C=1, kernel=linear, score=0.579, total=   0.1s
# [CV] C=1, kernel=linear ..............................................
# [CV] .................. C=1, kernel=linear, score=0.599, total=   0.1s
# [CV] C=1, kernel=linear ..............................................
# [CV] .................. C=1, kernel=linear, score=0.595, total=   0.1s
# [CV] C=1, kernel=linear ..............................................
# [CV] .................. C=1, kernel=linear, score=0.603, total=   0.1s
# [CV] C=1, kernel=linear ..............................................
# [CV] .................. C=1, kernel=linear, score=0.575, total=   0.1s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.591, total=   0.1s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.602, total=   0.2s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.595, total=   0.1s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.617, total=   0.2s
# [CV] C=10, kernel=linear .............................................
# [CV] ................. C=10, kernel=linear, score=0.581, total=   0.1s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.591, total=   0.6s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.607, total=   0.8s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.595, total=   0.8s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.615, total=   0.7s
# [CV] C=100, kernel=linear ............................................
# [CV] ................ C=100, kernel=linear, score=0.578, total=   0.7s
# [CV] C=1000, kernel=linear ...........................................
# [CV] ............... C=1000, kernel=linear, score=0.593, total=  11.8s
# [CV] C=1000, kernel=linear ...........................................
# [CV] ............... C=1000, kernel=linear, score=0.607, total=   7.4s
# [CV] C=1000, kernel=linear ...........................................
# [CV] ............... C=1000, kernel=linear, score=0.595, total=   5.4s
# [CV] C=1000, kernel=linear ...........................................
# [CV] ............... C=1000, kernel=linear, score=0.615, total=  21.3s
# [CV] C=1000, kernel=linear ...........................................
# [CV] ............... C=1000, kernel=linear, score=0.578, total=  12.4s
# [CV] C=1, degree=2, kernel=poly ......................................
# [CV] .......... C=1, degree=2, kernel=poly, score=0.577, total=   0.1s
# [CV] C=1, degree=2, kernel=poly ......................................
# [CV] .......... C=1, degree=2, kernel=poly, score=0.563, total=   0.1s
# [CV] C=1, degree=2, kernel=poly ......................................
# [CV] .......... C=1, degree=2, kernel=poly, score=0.606, total=   0.1s
# [CV] C=1, degree=2, kernel=poly ......................................
# [CV] .......... C=1, degree=2, kernel=poly, score=0.612, total=   0.1s
# [CV] C=1, degree=2, kernel=poly ......................................
# [CV] .......... C=1, degree=2, kernel=poly, score=0.612, total=   0.1s
# [CV] C=1, degree=3, kernel=poly ......................................
# [CV] .......... C=1, degree=3, kernel=poly, score=0.582, total=   0.1s
# [CV] C=1, degree=3, kernel=poly ......................................
# [CV] .......... C=1, degree=3, kernel=poly, score=0.602, total=   0.1s
# [CV] C=1, degree=3, kernel=poly ......................................
# [CV] .......... C=1, degree=3, kernel=poly, score=0.603, total=   0.1s
# [CV] C=1, degree=3, kernel=poly ......................................
# [CV] .......... C=1, degree=3, kernel=poly, score=0.615, total=   0.1s
# [CV] C=1, degree=3, kernel=poly ......................................
# [CV] .......... C=1, degree=3, kernel=poly, score=0.570, total=   0.1s
# [CV] C=1, degree=4, kernel=poly ......................................
# [CV] .......... C=1, degree=4, kernel=poly, score=0.554, total=   0.1s
# [CV] C=1, degree=4, kernel=poly ......................................
# [CV] .......... C=1, degree=4, kernel=poly, score=0.571, total=   0.1s
# [CV] C=1, degree=4, kernel=poly ......................................
# [CV] .......... C=1, degree=4, kernel=poly, score=0.589, total=   0.1s
# [CV] C=1, degree=4, kernel=poly ......................................
# [CV] .......... C=1, degree=4, kernel=poly, score=0.598, total=   0.1s
# [CV] C=1, degree=4, kernel=poly ......................................
# [CV] .......... C=1, degree=4, kernel=poly, score=0.559, total=   0.1s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] ......... C=10, degree=2, kernel=poly, score=0.563, total=   0.2s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] ......... C=10, degree=2, kernel=poly, score=0.607, total=   0.2s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] ......... C=10, degree=2, kernel=poly, score=0.598, total=   0.2s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] ......... C=10, degree=2, kernel=poly, score=0.640, total=   0.2s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] ......... C=10, degree=2, kernel=poly, score=0.623, total=   0.2s
# [CV] C=10, degree=3, kernel=poly .....................................
# [CV] ......... C=10, degree=3, kernel=poly, score=0.621, total=   0.2s
# [CV] C=10, degree=3, kernel=poly .....................................
# [CV] ......... C=10, degree=3, kernel=poly, score=0.649, total=   0.2s
# [CV] C=10, degree=3, kernel=poly .....................................
# [CV] ......... C=10, degree=3, kernel=poly, score=0.642, total=   0.2s
# [CV] C=10, degree=3, kernel=poly .....................................
# [CV] ......... C=10, degree=3, kernel=poly, score=0.651, total=   0.2s
# [CV] C=10, degree=3, kernel=poly .....................................
# [CV] ......... C=10, degree=3, kernel=poly, score=0.623, total=   0.2s
# [CV] C=10, degree=4, kernel=poly .....................................
# [CV] ......... C=10, degree=4, kernel=poly, score=0.618, total=   0.2s
# [CV] C=10, degree=4, kernel=poly .....................................
# [CV] ......... C=10, degree=4, kernel=poly, score=0.630, total=   0.2s
# [CV] C=10, degree=4, kernel=poly .....................................
# [CV] ......... C=10, degree=4, kernel=poly, score=0.631, total=   0.2s
# [CV] C=10, degree=4, kernel=poly .....................................
# [CV] ......... C=10, degree=4, kernel=poly, score=0.623, total=   0.2s
# [CV] C=10, degree=4, kernel=poly .....................................
# [CV] ......... C=10, degree=4, kernel=poly, score=0.623, total=   0.2s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ........ C=100, degree=2, kernel=poly, score=0.585, total=   0.4s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ........ C=100, degree=2, kernel=poly, score=0.610, total=   0.5s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ........ C=100, degree=2, kernel=poly, score=0.617, total=   0.6s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ........ C=100, degree=2, kernel=poly, score=0.626, total=   0.5s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ........ C=100, degree=2, kernel=poly, score=0.598, total=   0.5s
# [CV] C=100, degree=3, kernel=poly ....................................
# [CV] ........ C=100, degree=3, kernel=poly, score=0.630, total=   0.7s
# [CV] C=100, degree=3, kernel=poly ....................................
# [CV] ........ C=100, degree=3, kernel=poly, score=0.641, total=   0.5s
# [CV] C=100, degree=3, kernel=poly ....................................
# [CV] ........ C=100, degree=3, kernel=poly, score=0.654, total=   0.6s
# [CV] C=100, degree=3, kernel=poly ....................................
# [CV] ........ C=100, degree=3, kernel=poly, score=0.648, total=   0.7s
# [CV] C=100, degree=3, kernel=poly ....................................
# [CV] ........ C=100, degree=3, kernel=poly, score=0.595, total=   0.6s
# [CV] C=100, degree=4, kernel=poly ....................................
# [CV] ........ C=100, degree=4, kernel=poly, score=0.616, total=   0.5s
# [CV] C=100, degree=4, kernel=poly ....................................
# [CV] ........ C=100, degree=4, kernel=poly, score=0.649, total=   0.5s
# [CV] C=100, degree=4, kernel=poly ....................................
# [CV] ........ C=100, degree=4, kernel=poly, score=0.662, total=   0.5s
# [CV] C=100, degree=4, kernel=poly ....................................
# [CV] ........ C=100, degree=4, kernel=poly, score=0.648, total=   0.5s
# [CV] C=100, degree=4, kernel=poly ....................................
# [CV] ........ C=100, degree=4, kernel=poly, score=0.654, total=   0.5s
# [CV] C=1000, degree=2, kernel=poly ...................................
# [CV] ....... C=1000, degree=2, kernel=poly, score=0.585, total=   3.4s
# [CV] C=1000, degree=2, kernel=poly ...................................
# [CV] ....... C=1000, degree=2, kernel=poly, score=0.624, total=   4.2s
# [CV] C=1000, degree=2, kernel=poly ...................................
# [CV] ....... C=1000, degree=2, kernel=poly, score=0.603, total=   3.4s
# [CV] C=1000, degree=2, kernel=poly ...................................
# [CV] ....... C=1000, degree=2, kernel=poly, score=0.626, total=   3.8s
# [CV] C=1000, degree=2, kernel=poly ...................................
# [CV] ....... C=1000, degree=2, kernel=poly, score=0.595, total=   4.2s
# [CV] C=1000, degree=3, kernel=poly ...................................
# [CV] ....... C=1000, degree=3, kernel=poly, score=0.641, total=   7.9s
# [CV] C=1000, degree=3, kernel=poly ...................................
# [CV] ....... C=1000, degree=3, kernel=poly, score=0.627, total=   5.3s
# [CV] C=1000, degree=3, kernel=poly ...................................
# [CV] ....... C=1000, degree=3, kernel=poly, score=0.637, total=   8.7s
# [CV] C=1000, degree=3, kernel=poly ...................................
# [CV] ....... C=1000, degree=3, kernel=poly, score=0.670, total=   7.1s
# [CV] C=1000, degree=3, kernel=poly ...................................
# [CV] ....... C=1000, degree=3, kernel=poly, score=0.612, total=   6.8s
# [CV] C=1000, degree=4, kernel=poly ...................................
# [CV] ....... C=1000, degree=4, kernel=poly, score=0.657, total=   3.0s
# [CV] C=1000, degree=4, kernel=poly ...................................
# [CV] ....... C=1000, degree=4, kernel=poly, score=0.599, total=   3.0s
# [CV] C=1000, degree=4, kernel=poly ...................................
# [CV] ....... C=1000, degree=4, kernel=poly, score=0.654, total=   3.5s
# [CV] C=1000, degree=4, kernel=poly ...................................
# [CV] ....... C=1000, degree=4, kernel=poly, score=0.626, total=   3.5s
# [CV] C=1000, degree=4, kernel=poly ...................................
# [CV] ....... C=1000, degree=4, kernel=poly, score=0.631, total=   4.4s
# [Parallel(n_jobs=1)]: Done 205 out of 205 | elapsed:  2.9min finished
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf', max_iter=-1,
#     probability=False, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
print(svc_mod.best_params_)
# Out:
# {'C': 10, 'gamma': 1, 'kernel': 'rbf'}

# %%
#Performance (Accuracy)
print('Accuracy (generalization)',svc_mod.score(X_test,y_test)) #Accuracy (generalization)  
print('Accuracy (memorization)',svc_mod.score(X_train,y_train)) #Accuracy (memorization)

#Comparing other metrics (f1_score)
print('F1_score (generalization)',f1_score(y_test,svc_mod.predict(X_test),average="weighted")) #F1_score (generalization)  
print('F1_score (memorization)',f1_score(y_train,svc_mod.predict(X_train),average="weighted")) #F1_score (memorization)
# Out:
# Accuracy (generalization) 0.7005988023952096
# Accuracy (memorization) 0.8911830357142857
# F1_score (generalization) 0.6974699103046533
# F1_score (memorization) 0.8907505284679805

# %% [markdown]
# #### Applying Model

# %%
srbf=SVC(C=10.0,kernel='rbf',gamma=1)
srbf.fit(X_train, y_train)
# Out:
# SVC(C=10.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf', max_iter=-1,
#     probability=False, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
#Performance (Accuracy)
print('Accuracy (generalization)',srbf.score(X_test,y_test)) #Accuracy (generalization)  
print('Accuracy (memorization)',srbf.score(X_train,y_train)) #Accuracy (memorization)

#Comparing other metrics (f1_score)
print('F1_score (generalization)',f1_score(y_test,srbf.predict(X_test),average="weighted")) #F1_score (generalization)  
print('F1_score (memorization)',f1_score(y_train,srbf.predict(X_train),average="weighted")) #F1_score (memorization)
# Out:
# Accuracy (generalization) 0.7005988023952096
# Accuracy (memorization) 0.8911830357142857
# F1_score (generalization) 0.6974699103046533
# F1_score (memorization) 0.8907505284679805

# %% [markdown]
# ### 4.4. Random Forest

# %% [markdown]
# #### Tuning Hyperparameters

# %%
#Number of trees
score=[]
t=[]
n_trees=[]
for i in range(10,300,10):
    n_trees.append(i)
    start_time = time.time()
    cforest = RandomForestClassifier(criterion='entropy',n_estimators=i,max_depth=10,random_state=1, n_jobs=2) #Creating Instance
    cforest.fit(X_train, y_train) #Learning the decision boundaries
    y_pred = cforest.predict(X_test)
    score.append(f1_score(y_test, y_pred,average="weighted"))
    t.append(time.time() - start_time)

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Number of trees')
ax1.set_ylabel('F1_score', color=color)
ax1.set_ylim([0.5,0.8])
ax1.plot(n_trees, score, '-o',color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('time (s)', color=color)  # we already handled the x-label with ax1
ax2.plot(n_trees, t, '-o',color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
#max_depth
score=[]
max_d=[]
score_train=[]
for i in range(1,30):
    max_d.append(i)
    cforest = RandomForestClassifier(criterion='entropy',n_estimators=200,max_depth=i,random_state=1, n_jobs=2) #Creating Instance
    cforest.fit(X_train, y_train) #Learning the decision boundaries
    train_pred = cforest.predict(X_train)
    score_train.append(f1_score(y_train, train_pred,average="weighted"))
    y_pred = cforest.predict(X_test)
    score.append(f1_score(y_test, y_pred,average="weighted"))

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Max_Depth')
ax1.set_ylabel('F1_score')
ax1.set_ylim([0,1.01])
ax1.plot(max_d, score, '-o',color=color,label='Test F1_score')

color = 'tab:blue'
ax1.plot(max_d, score_train, '-o',color=color,label='Train F1_score')

ax1.legend(loc="lower right")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
#min_samples_split
score=[]
score_train=[]
min_samples=[]
for i in range(1,10,2):
    min_samples.append(i/10)
    cforest = RandomForestClassifier(criterion='entropy',n_estimators=200,max_depth=10,min_samples_split=i/10,random_state=1, n_jobs=2) #Creating Instance
    cforest.fit(X_train, y_train) #Learning the decision boundaries
    train_pred = cforest.predict(X_train)
    score_train.append(f1_score(y_train, train_pred,average="weighted"))
    y_pred = cforest.predict(X_test)
    score.append(f1_score(y_test, y_pred,average="weighted"))

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('min_samples_split')
ax1.set_ylabel('F1_score')
ax1.set_ylim([0,1.01])
ax1.plot(min_samples, score, '-o',color=color,label='Test F1_score')

color = 'tab:blue'
ax1.plot(min_samples, score_train, '-o',color=color,label='Train F1_score')

ax1.legend(loc="lower left")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# #### Applying Model

# %%
cforest = RandomForestClassifier(criterion='entropy',n_estimators=200,max_depth=7,random_state=1, n_jobs=2) #Creating Instance
cforest.fit(X_train, y_train) #Learning the decision boundaries
y_pred = cforest.predict(X_test)

# %%
#Compare against true labels (Accuracy)
print('Accuracy (generalization)',cforest.score(X_test,y_test)) #Accuracy (generalization)  
print('Accuracy (memorization)',cforest.score(X_train,y_train)) #Accuracy (memorization)
# Out:
# Accuracy (generalization) 0.6706586826347305
# Accuracy (memorization) 0.8063616071428571

# %%
#Comparing other metrics (f1_score)
print('F1_score (generalization)',f1_score(y_test,cforest.predict(X_test),average="weighted")) #F1_score (generalization)  
print('F1_score (memorization)',f1_score(y_train,cforest.predict(X_train),average="weighted")) #F1_score (memorization)
# Out:
# F1_score (generalization) 0.66356261911417
# F1_score (memorization) 0.8031509053086673

# %%
#Feature Importance
importances = cforest.feature_importances_
# get sort indices in descending order

indices = np.argsort(importances)[::-1]

for f in range(X_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30, X.columns.values[indices[f]], importances[indices[f]]))

plt.figure()
plt.title('Feature Importances')
plt.bar(range(X_train.shape[1]),importances[indices],align='center',alpha=0.5)

plt.xticks(range(X_train.shape[1]), X.columns.values[indices], rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.tight_layout()
plt.savefig('fig-forest-feature-importances.png', dpi=300)
plt.show()
# Out:
#  1) NM_M                           0.279616
#  2) PE                             0.164690
#  3) GR                             0.156572
#  4) ILD_log10                      0.144722
#  5) PHIND                          0.108253
#  6) DeltaPHI                       0.078093
#  7) RELPOS                         0.068054

# %% [markdown]
# ### 4.5 Multi-Layer Perceptron ( A Neural Network Implementation in Sklearn)
#
# ![image.png](attachment:image.png)
#
# https://scikit-learn.org/stable/modules/neural_networks_supervised.html#mlp-tips

# %% [markdown]
# #### Tuning Hyperparameters

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV 

parameters = {'solver': ['lbfgs'], 'max_iter': [1000,1400,1800,2000,2500], 'alpha': 10.0 ** -np.arange(1, 5), 'hidden_layer_sizes':[10,20,50,100]}
MLPCla = GridSearchCV(MLPClassifier(), parameters, n_jobs=-1, refit=True, verbose=3)

# %%
MLPCla.fit(X_train, y_train)
print(MLPCla.best_params_)
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done 400 out of 400 | elapsed: 12.5min finished
# {'alpha': 0.1, 'hidden_layer_sizes': 100, 'max_iter': 2500, 'solver': 'lbfgs'}

# %% [markdown]
# #### Applying Model

# %%
MLPCla = MLPClassifier(solver='lbfgs', alpha=0.1, hidden_layer_sizes=(100,), max_iter=1000)
#MLPCla = MLPClassifier(solver='lbfgs', alpha=1e-2, hidden_layer_sizes=(100,), random_state=1)
MLPCla.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.1, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_fun=15000, max_iter=1000,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=None, shuffle=True, solver='lbfgs',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
#Performance (Accuracy)
print('Accuracy (generalization)',MLPCla.score(X_test,y_test)) #Accuracy (generalization)  
print('Accuracy (memorization)',MLPCla.score(X_train,y_train)) #Accuracy (memorization)

#Comparing other metrics (f1_score)
print('F1_score (generalization)',f1_score(y_test,MLPCla.predict(X_test),average="weighted")) #F1_score (generalization)  
print('F1_score (memorization)',f1_score(y_train,MLPCla.predict(X_train),average="weighted")) #F1_score (memorization)
# Out:
# Accuracy (generalization) 0.6838323353293413
# Accuracy (memorization) 0.9905133928571429
# F1_score (generalization) 0.6818271925456162
# F1_score (memorization) 0.9905153604458989

# %% [markdown]
# ### 4.6 Naive Bayes

# %% [markdown]
# #### Tuning Hyperparameters

# %%
from sklearn.naive_bayes import GaussianNB

score=[]
score_train=[]
C=[]
for i in range(1,10,1):
    C.append(1*(10**(-i)))
    classifier = GaussianNB(var_smoothing=1*(10**(-i))) 
    classifier.fit(X_train, y_train)
    train_pred = classifier.predict(X_train)
    score_train.append(f1_score(y_train, train_pred,average="weighted"))
    y_pred = classifier.predict(X_test)
    score.append(f1_score(y_test, y_pred,average="weighted"))

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('var_smoothing')
ax1.set_ylabel('F1_score')
ax1.set_ylim([0.5,0.60])
ax1.plot(C, score, '-o',color=color,label='Test F1_score')

color = 'tab:blue'
ax1.plot(C, score_train, '-o',color=color,label='Train F1_score')

ax1.legend(loc="lower right")

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# #### Applying Model

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB(var_smoothing = 0.1)
gnb.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=0.1)

# %%
#Performance (Accuracy)
print('Accuracy (generalization)',gnb.score(X_test,y_test)) #Accuracy (generalization)  
print('Accuracy (memorization)',gnb.score(X_train,y_train)) #Accuracy (memorization)

#Comparing other metrics (f1_score)
print('F1_score (generalization)',f1_score(y_test,gnb.predict(X_test),average="weighted")) #F1_score (generalization)  
print('F1_score (memorization)',f1_score(y_train,gnb.predict(X_train),average="weighted")) #F1_score (memorization)
# Out:
# Accuracy (generalization) 0.5604790419161677
# Accuracy (memorization) 0.5625
# F1_score (generalization) 0.5403445093747469
# F1_score (memorization) 0.5455043407470608

# %% [markdown]
# ### 4.7. Scores for all classifiers

# %% [markdown]
# ![Score_Classifiers_SEG_data](Score_Classifiers_SEG_data.png)

# %% [markdown]
# ##### Additional Classifiers Tested:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5. Deployment (Predict targets for new dataset)

# %%
test_well
# Out:
#         Facies Formation Well Name     GR  ILD_log10  DeltaPHI   PHIND   PE  \
# Depth
# 2774.5       2     A1 SH   SHANKLE  98.36      0.642      -0.1  18.685  2.9
# 2775.0       2     A1 SH   SHANKLE  97.57      0.631       7.9  16.745  3.2
# 2775.5       2     A1 SH   SHANKLE  98.41      0.615      12.8  14.105  3.2
# 2776.0       2     A1 SH   SHANKLE  85.92      0.597      13.0  13.385  3.4
# 2776.5       2     A1 SH   SHANKLE  83.16      0.592      12.3  13.345  3.4
# ...        ...       ...       ...    ...        ...       ...     ...  ...
# 3006.0       8      C LM   SHANKLE  32.84      1.120      -2.2   3.455  5.1
# 3006.5       8      C LM   SHANKLE  25.16      1.112      -1.6   2.890  4.8
# 3007.0       8      C LM   SHANKLE  25.16      1.112      -1.6   2.890  4.8
# 3007.5       4      C LM   SHANKLE  26.22      1.092      -0.4   3.400  4.5
# 3008.0       4      C LM   SHANKLE  65.36      1.026       1.6   4.715  4.5
#
#         NM_M  RELPOS Facies_Label
# Depth
# 2774.5     1   1.000         CSiS
# 2775.0     1   0.984         CSiS
# 2775.5     1   0.968         CSiS
# 2776.0     1   0.952         CSiS
# 2776.5     1   0.935         CSiS
# ...      ...     ...          ...
# 3006.0     2   0.060           PS
# 3006.5     2   0.045           PS
# 3007.0     2   0.030           PS
# 3007.5     2   0.030         SiSh
# 3008.0     2   0.015         SiSh
#
# [449 rows x 11 columns]

# %%
X = test_well.drop(['Facies','Formation','Well Name','Facies_Label'], axis = 1) #Features: Feature vector
y_test = test_well['Facies'] #Target: Facies

X
# Out:
#            GR  ILD_log10  DeltaPHI   PHIND   PE  NM_M  RELPOS
# Depth
# 2774.5  98.36      0.642      -0.1  18.685  2.9     1   1.000
# 2775.0  97.57      0.631       7.9  16.745  3.2     1   0.984
# 2775.5  98.41      0.615      12.8  14.105  3.2     1   0.968
# 2776.0  85.92      0.597      13.0  13.385  3.4     1   0.952
# 2776.5  83.16      0.592      12.3  13.345  3.4     1   0.935
# ...       ...        ...       ...     ...  ...   ...     ...
# 3006.0  32.84      1.120      -2.2   3.455  5.1     2   0.060
# 3006.5  25.16      1.112      -1.6   2.890  4.8     2   0.045
# 3007.0  25.16      1.112      -1.6   2.890  4.8     2   0.030
# 3007.5  26.22      1.092      -0.4   3.400  4.5     2   0.030
# 3008.0  65.36      1.026       1.6   4.715  4.5     2   0.015
#
# [449 rows x 7 columns]

# %%
#If PE is removed
#X = test_well.drop(['Facies','Formation','Well Name','PE','Facies_Label'], axis = 1) #Features: Feature vector
#y_test = test_well['Facies'] #Target: Facies

# %%
#Scaling
X_test = rscaler.transform(X)
X_test=pd.DataFrame(X_test,index=X.index, columns=X.columns)
X_test
# Out:
#               GR  ILD_log10  DeltaPHI     PHIND        PE  NM_M    RELPOS
# Depth
# 2774.5  0.929395   0.035032 -0.692978  0.857349 -0.590000  -1.0  0.903960
# 2775.0  0.907305   0.000000  0.847187  0.614005 -0.340000  -1.0  0.872277
# 2775.5  0.930793  -0.050955  1.790538  0.282856 -0.340000  -1.0  0.840594
# 2776.0  0.581545  -0.108280  1.829042  0.192543 -0.173333  -1.0  0.808911
# 2776.5  0.504369  -0.124204  1.694277  0.187525 -0.173333  -1.0  0.775248
# ...          ...        ...       ...       ...       ...   ...       ...
# 3006.0 -0.902691   1.557325 -1.097271 -1.053028  1.243333   0.0 -0.957426
# 3006.5 -1.117441   1.531847 -0.981759 -1.123899  0.993333   0.0 -0.987129
# 3007.0 -1.117441   1.531847 -0.981759 -1.123899  0.993333   0.0 -1.016832
# 3007.5 -1.087801   1.468153 -0.750734 -1.059927  0.743333   0.0 -1.016832
# 3008.0  0.006641   1.257962 -0.365693 -0.894979  0.743333   0.0 -1.046535
#
# [449 rows x 7 columns]

# %%
def compare_facies_plot(logs, compadre, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')
    
    ztop=logs.Depth.min(); zbot=logs.Depth.max()
    
    cluster1 = np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)
    cluster2 = np.repeat(np.expand_dims(logs[compadre].values,1), 100, 1)
    
    f, ax = plt.subplots(nrows=1, ncols=7, figsize=(9, 12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.ILD_log10, logs.Depth, '-')
    ax[2].plot(logs.DeltaPHI, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.PHIND, logs.Depth, '-', color='r')
    ax[4].plot(logs.PE, logs.Depth, '-', color='black')
    im1 = ax[5].imshow(cluster1, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    im2 = ax[6].imshow(cluster2, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)
    
    divider = make_axes_locatable(ax[6])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im2, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS', 
                                'SiSh', ' MS ', ' WS ', ' D  ', 
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')
    
    for i in range(len(ax)-2):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)
    
    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("ILD_log10")
    ax[1].set_xlim(logs.ILD_log10.min(),logs.ILD_log10.max())
    ax[2].set_xlabel("DeltaPHI")
    ax[2].set_xlim(logs.DeltaPHI.min(),logs.DeltaPHI.max())
    ax[3].set_xlabel("PHIND")
    ax[3].set_xlim(logs.PHIND.min(),logs.PHIND.max())
    ax[4].set_xlabel("PE")
    ax[4].set_xlim(logs.PE.min(),logs.PE.max())
    ax[5].set_xlabel('Facies')
    ax[6].set_xlabel(compadre)
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    ax[6].set_xticklabels([])
    f.suptitle('Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)

# %%
test_well.reset_index(inplace = True)

# %% [markdown]
# ### 5.1. Logistic Regression

# %%
y_pred=classifier.predict(X_test)
test_well['Prediction'] = y_pred

# %%
compare_facies_plot(test_well, 'Prediction', facies_colors)

# %%
target_names = ['SS', 'CSiS', 'FSiS', 'SiSh','MS', 'WS', 'D','PS','BS']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#           SS       0.39      1.00      0.56        89
#         CSiS       0.70      0.08      0.14        89
#         FSiS       0.85      0.43      0.57       117
#         SiSh       0.00      0.00      0.00         7
#           MS       0.00      0.00      0.00        19
#           WS       0.00      0.00      0.00        71
#            D       0.20      0.76      0.31        17
#           PS       1.00      0.03      0.05        40
#           BS       0.00      0.00      0.00         0
#
#     accuracy                           0.36       449
#    macro avg       0.35      0.26      0.18       449
# weighted avg       0.53      0.36      0.30       449

# %%
#Confusion Matrix
cf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(cf_matrix, annot=True, annot_kws={"size": 12},cmap='Blues',fmt="d",xticklabels=target_names,yticklabels=target_names)

plt.show()

# %% [markdown]
# ### 5.2. K-Nearest Neighbor

# %%
y_pred=knn.predict(X_test)
test_well['Prediction'] = y_pred

# %%
compare_facies_plot(test_well, 'Prediction', facies_colors)

# %%
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#           SS       0.64      0.26      0.37        89
#         CSiS       0.39      0.83      0.53        89
#         FSiS       0.88      0.56      0.68       117
#         SiSh       0.11      0.29      0.16         7
#           MS       0.00      0.00      0.00        19
#           WS       0.68      0.56      0.62        71
#            D       1.00      0.29      0.45        17
#           PS       0.50      0.53      0.51        40
#           BS       0.00      0.00      0.00         0
#
#     accuracy                           0.51       449
#    macro avg       0.47      0.37      0.37       449
# weighted avg       0.62      0.51      0.52       449

# %%
#Confusion Matrix
cf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(cf_matrix, annot=True, annot_kws={"size": 12},cmap='Blues',fmt="d",xticklabels=target_names,yticklabels=target_names)

plt.show()

# %% [markdown]
# ### 5.3. Support Vector Machine

# %%
y_pred = srbf.predict(X_test)
test_well['Prediction'] = y_pred

# %%
compare_facies_plot(test_well, 'Prediction', facies_colors)

# %%
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#           SS       0.40      0.09      0.15        89
#         CSiS       0.33      0.73      0.46        89
#         FSiS       0.79      0.42      0.55       117
#         SiSh       0.00      0.00      0.00         7
#           MS       0.00      0.00      0.00        19
#           WS       0.66      0.52      0.58        71
#            D       1.00      0.35      0.52        17
#           PS       0.28      0.55      0.37        40
#           BS       0.00      0.00      0.00         0
#
#     accuracy                           0.42       449
#    macro avg       0.38      0.30      0.29       449
# weighted avg       0.52      0.42      0.41       449

# %%
#Confusion Matrix
cf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(cf_matrix, annot=True, annot_kws={"size": 12},cmap='Blues',fmt="d",xticklabels=target_names,yticklabels=target_names)

plt.show()

# %% [markdown]
# ### 5.4. Random Forest

# %%
y_pred = cforest.predict(X_test)
test_well['Prediction'] = y_pred

# %%
compare_facies_plot(test_well, 'Prediction', facies_colors)

# %%
target_names = ['SS', 'CSiS', 'FSiS', 'SiSh','MS', 'WS', 'D','PS']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#           SS       0.36      0.06      0.10        89
#         CSiS       0.31      0.80      0.45        89
#         FSiS       0.79      0.36      0.49       117
#         SiSh       0.06      0.14      0.08         7
#           MS       0.00      0.00      0.00        19
#           WS       0.69      0.66      0.68        71
#            D       1.00      0.59      0.74        17
#           PS       0.52      0.70      0.60        40
#
#     accuracy                           0.45       449
#    macro avg       0.47      0.41      0.39       449
# weighted avg       0.53      0.45      0.43       449

# %%
#Confusion Matrix
cf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(cf_matrix, annot=True, annot_kws={"size": 12},cmap='Blues',fmt="d",xticklabels=target_names,yticklabels=target_names)

plt.show()

# %% [markdown]
# ### 5.5.  Multi-Layer Perceptron (Sklearn Supervised Neural Network Models)

# %%
y_pred=MLPCla.predict(X_test)
test_well['Prediction'] = y_pred

# %%
compare_facies_plot(test_well, 'Prediction', facies_colors)

# %%
target_names = ['SS', 'CSiS', 'FSiS', 'SiSh','MS', 'WS', 'D','PS','BS']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#           SS       0.68      0.24      0.35        89
#         CSiS       0.32      0.65      0.43        89
#         FSiS       0.61      0.39      0.48       117
#         SiSh       0.07      0.14      0.09         7
#           MS       0.23      0.32      0.27        19
#           WS       0.57      0.45      0.50        71
#            D       0.93      0.82      0.87        17
#           PS       0.54      0.55      0.54        40
#           BS       0.00      0.00      0.00         0
#
#     accuracy                           0.45       449
#    macro avg       0.44      0.40      0.39       449
# weighted avg       0.54      0.45      0.45       449

# %%
#Confusion Matrix
cf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(cf_matrix, annot=True, annot_kws={"size": 12},cmap='Blues',fmt="d",xticklabels=target_names,yticklabels=target_names)

plt.show()

# %% [markdown]
# ### 5.6.  Naive Bayes

# %%
y_pred=gnb.predict(X_test)
test_well['Prediction'] = y_pred

# %%
compare_facies_plot(test_well, 'Prediction', facies_colors)

# %%
target_names = ['SS', 'CSiS', 'FSiS', 'SiSh','MS', 'WS', 'D','PS']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#           SS       0.76      0.61      0.68        89
#         CSiS       0.40      0.62      0.48        89
#         FSiS       0.75      0.57      0.65       117
#         SiSh       0.06      0.14      0.08         7
#           MS       0.25      0.16      0.19        19
#           WS       0.63      0.75      0.68        71
#            D       0.86      0.71      0.77        17
#           PS       0.61      0.35      0.44        40
#
#     accuracy                           0.58       449
#    macro avg       0.54      0.49      0.50       449
# weighted avg       0.62      0.58      0.59       449

# %%
#Confusion Matrix
cf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(cf_matrix, annot=True, annot_kws={"size": 12},cmap='Blues',fmt="d",xticklabels=target_names,yticklabels=target_names)

plt.show()

# %% [markdown]
# ## Does Reducing Dimensions help?

# %%
## Resetting the variables X and y to point to original training dataset instead of the test_well

X = data.drop(['Facies','Formation','Well Name','Facies_Label'], axis = 1) #Features: Feature vector
y = data['Facies'] #Target: Facies

# %%
## Performing Train Test split exactly as before
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1000)
print('Dimensions of X_train:',X_train.shape)
print('Dimensions of X_test:',X_test.shape)
# Out:
# Dimensions of X_train: (1948, 7)
# Dimensions of X_test: (835, 7)

# %%
#Scaling using the same Robust Scaler as used before

rscaler.fit(X_train)

X_train_scaled = rscaler.transform(X_train) # transform the train dataset to standardized data

X_test_scaled  = rscaler.transform(X_test) #Scale the test data using the parameters learnt from the training dataset

X_train=pd.DataFrame(X_train_scaled,index=X_train.index, columns=X_test.columns)
X_test=pd.DataFrame(X_test_scaled,index=X_test.index, columns=X_test.columns)

#Outlier Removal
iforest.fit(X_train) #Training the model

#Predictions
X_train_predict = iforest.predict(X_train) 
X_train['Predict']=X_train_predict
X_train['Predict'] = X_train['Predict'].astype('category')

#Removing Outliers
X_train['y_train']=y_train
X_train = X_train[X_train['Predict'] == 1]

y_train=X_train['y_train']
X_train = X_train.drop(['Predict','y_train'], axis = 1)

# %%
print(len(y_train))
X_train #Data ready to be used with Scaling and Outlier Removal done as before
# Out:
# 1792
#               GR  ILD_log10  DeltaPHI     PHIND        PE  NM_M    RELPOS
# Depth
# 2931.5 -0.511975   0.719745 -0.757665 -0.874283  0.554167   0.0  0.709901
# 3004.0 -0.426774   0.888535  0.789431 -0.534981  0.993333   0.0 -0.125743
# 2714.0 -1.392031   0.512739 -0.654474 -0.263414  1.410000   0.0  0.486139
# 3121.5 -0.430717   1.060510 -0.110603 -0.481294 -0.348333   0.0  0.248515
# 2857.5  0.704383  -0.159236  0.410935  0.201700 -0.177500  -1.0  0.543564
# ...          ...        ...       ...       ...       ...   ...       ...
# 2809.0 -1.158602   0.466789 -1.097271 -0.307316  0.700833   0.0  0.846535
# 2927.0 -0.335477   0.621019 -0.457718 -0.879927  0.333333   0.0  0.903960
# 2927.5  0.247396  -0.423567  0.462146  0.627176 -0.090000  -1.0 -0.636634
# 2674.5  0.318420  -0.025478  0.596910  1.473862 -0.840000  -1.0  0.498020
# 2866.5 -0.153722  -1.079618  0.537999  0.957948 -0.550833  -1.0 -0.266337
#
# [1792 rows x 7 columns]

# %%
from sklearn.feature_selection import f_classif, chi2

# f_classif is used when one variable (feature) is categorical and the other (target) is continuous
# chi square is used when we have two categorical variables (e.g., gender and alive/dead)

# %%
F, p = f_classif(X_train, y_train)  #learn preprocessing from train

# large p are lower importance feature
# small p are higher importance feature

# %%
plt.figure()
plt.plot(p, 'o')
plt.ylabel('p value')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %%
plt.figure()
plt.plot(F, 'o')
plt.ylabel('F value')
plt.xlabel('features')
# Out:
# Text(0.5, 0, 'features')

# %% [markdown]
# A large f value and a small p value means the feature is significant
#
# Low p-value indicates informative features
#
# Here, in this case, all features seem to be really important given the very low p values.

# %%
print('no. of features with p-value < threshold: {}'.format(len(p[p<0.00001])))
# Out:
# no. of features with p-value < threshold: 7

# %%
#### Compute the threshold for feature selection#SelectPercentile, 
### which selects a percentile of the original features (we select 50%)
# We have to define a threshold on the p-value of the statistical test to decide how many features to keep. 

from sklearn.feature_selection import SelectPercentile

# use SelectPercentile to select 30% of features:

select = SelectPercentile(percentile=90)
select.fit(X_train, y_train)

# transform training set by reducing number of features:
X_train_red = select.transform(X_train)

# transform training set by reducing number of features:
X_test_red = select.transform(X_test)

print("before: {}".format(X_train.shape))
print("after: {}".format(X_train_red.shape))
# Out:
# before: (1792, 7)
# after: (1792, 6)

# %%
mask = select.get_support()
print(mask)
# visualize the mask. black is True, white is False
plt.matshow(mask.reshape(1, -1), cmap='gray_r')
# Out:
# [ True  True  True  True  True  True False]

# %%
print('Column Eliminated = ',X_train.columns[~mask])
# Out:
# Column Eliminated =  Index(['RELPOS'], dtype='object')

# %%
X_train[X_train.columns[mask]] # Reduced Dimension Data finally used == X_train_red
# Out:
#               GR  ILD_log10  DeltaPHI     PHIND        PE  NM_M
# Depth
# 2931.5 -0.511975   0.719745 -0.757665 -0.874283  0.554167   0.0
# 3004.0 -0.426774   0.888535  0.789431 -0.534981  0.993333   0.0
# 2714.0 -1.392031   0.512739 -0.654474 -0.263414  1.410000   0.0
# 3121.5 -0.430717   1.060510 -0.110603 -0.481294 -0.348333   0.0
# 2857.5  0.704383  -0.159236  0.410935  0.201700 -0.177500  -1.0
# ...          ...        ...       ...       ...       ...   ...
# 2809.0 -1.158602   0.466789 -1.097271 -0.307316  0.700833   0.0
# 2927.0 -0.335477   0.621019 -0.457718 -0.879927  0.333333   0.0
# 2927.5  0.247396  -0.423567  0.462146  0.627176 -0.090000  -1.0
# 2674.5  0.318420  -0.025478  0.596910  1.473862 -0.840000  -1.0
# 2866.5 -0.153722  -1.079618  0.537999  0.957948 -0.550833  -1.0
#
# [1792 rows x 6 columns]

# %% [markdown]
# ### Comparing Generalization Accuracy Scores to check if Reduction in Dimensions Improves it
# #### Logistic Regression

# %%
classifier = LogisticRegression(C=2) 
classifier_red = LogisticRegression(C=2)

classifier.fit(X_train, y_train)
print("Score with all scaled features: %f" % classifier.score(X_test, y_test))

classifier_red.fit(X_train_red, y_train)
print("Score with only selected scaled features: %f" % classifier_red.score(X_test_red, y_test))
# Out:
# Score with all scaled features: 0.578443
# Score with only selected scaled features: 0.561677

# %% [markdown]
# #### K-Nearest Neighbor

# %%
knn = KNeighborsClassifier(n_neighbors=9,p=1)
knn_red = KNeighborsClassifier(n_neighbors=9,p=1)

knn.fit(X_train, y_train)
print("Score with all scaled features: %f" % knn.score(X_test, y_test))

knn_red.fit(X_train_red, y_train)
print("Score with only selected scaled features: %f" % knn_red.score(X_test_red, y_test))
# Out:
# Score with all scaled features: 0.668263
# Score with only selected scaled features: 0.627545

# %% [markdown]
# #### Support Vector Machine Classifier

# %%
srbf=SVC(C=10.0,kernel='rbf',gamma=1)
srbf_red = SVC(C=10.0,kernel='rbf',gamma=1)

srbf.fit(X_train, y_train)
print("Score with all scaled features: %f" % srbf.score(X_test, y_test))

srbf_red.fit(X_train_red, y_train)
print("Score with only selected scaled features: %f" % srbf_red.score(X_test_red, y_test))
# Out:
# Score with all scaled features: 0.702994
# Score with only selected scaled features: 0.640719

# %% [markdown]
# #### Random Forest

# %%
cforest = RandomForestClassifier(criterion='entropy',n_estimators=200,max_depth=7,random_state=1, n_jobs=2)
cforest_red = RandomForestClassifier(criterion='entropy',n_estimators=200,max_depth=7,random_state=1, n_jobs=2)

cforest.fit(X_train, y_train)
print("Score with all scaled features: %f" % cforest.score(X_test, y_test))

cforest_red.fit(X_train_red, y_train)
print("Score with only selected scaled features: %f" % cforest_red.score(X_test_red, y_test))
# Out:
# Score with all scaled features: 0.665868
# Score with only selected scaled features: 0.629940

# %% [markdown]
# #### MLP Classifier

# %%
MLPCla = MLPClassifier(solver='lbfgs', alpha=0.1, hidden_layer_sizes=(100,), max_iter=1000)
MLPCla_red = MLPClassifier(solver='lbfgs', alpha=0.1, hidden_layer_sizes=(100,), max_iter=1000)

MLPCla.fit(X_train, y_train)
print("Score with all scaled features: %f" % MLPCla.score(X_test, y_test))

MLPCla_red.fit(X_train_red, y_train)
print("Score with only selected scaled features: %f" % MLPCla_red.score(X_test_red, y_test))
# Out:
# Score with all scaled features: 0.691018
# Score with only selected scaled features: 0.611976

# %% [markdown]
# #### Gaussian Naive Bayes

# %%
gnb = GaussianNB(var_smoothing = 0.1)
gnb_red = GaussianNB(var_smoothing = 0.1)

gnb.fit(X_train, y_train)
print("Score with all scaled features: %f" % gnb.score(X_test, y_test))

gnb_red.fit(X_train_red, y_train)
print("Score with only selected scaled features: %f" % gnb_red.score(X_test_red, y_test))
# Out:
# Score with all scaled features: 0.560479
# Score with only selected scaled features: 0.546108

# %% [markdown]
# ### Since we see a reduction in performance in terms of generalization accuracy score for every model built
# ### Dimensionality Reduction does not help this case since the number of features is already very low
